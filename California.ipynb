# %% [markdown]
# # California housing prices 💸
# --------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('housing.csv')
print('Importamos el .csv (ubicado en el mismo directorio que nuestro archivo) y mostramos el resultado obtenido:\n\n', df)
# Out:
# Importamos el .csv (ubicado en el mismo directorio que nuestro archivo) y mostramos el resultado obtenido:
#
#         longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# ...

# %%
#Mejor visualizacion
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#Para visualizar los 10 primeros elementos
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
print('Obtenemos el tamaño:', df.shape)
# Out:
# Obtenemos el tamaño: (20640, 10)

# %%
print('Obtenemos algunos estadísticos\n')
df.describe()
# Out:
# Obtenemos algunos estadísticos
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# ...

# %%
#Calculemos la poblacion total
population = df['population']
population
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: population, Length: 20640, dtype: float64

# %%
length = len(population)
total_population = sum(population)
print('La población total es: ',total_population)
# Out:
# La población total es:  29421840.0

# %%
# Borra todas las filas con NaN si hubiese
df.dropna()
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#Visualizamos qué valores toma el campo longitude
df['longitude'].unique()
# Out:
# array([-122.23, -122.22, -122.24, -122.25, -122.26, -122.27, -122.28,
#        -122.29, -122.3 , -122.21, -122.2 , -122.19, -122.18, -122.13,
#        -122.16, -122.17, -122.15, -122.14, -122.12, -122.33, -122.34,
#        -122.06, -122.07, -122.08, -122.09, -122.1 , -122.11, -122.03,
#        -121.97, -122.02, -122.04, -122.05, -121.99, -122.01, -121.96,
#        -121.98, -122.  , -121.93, -121.94, -121.95, -121.92, -121.89,
#        -121.91, -121.9 , -121.88, -121.87, -121.85, -121.86, -121.84,
#        -121.82, -121.77, -121.62, -121.61, -121.72, -121.73, -121.75,
#        -121.8 , -121.76, -121.78, -121.79, -119.78, -119.93, -120.  ,
#        -120.56, -120.59, -120.55, -120.25, -120.79, -120.8 , -120.65,
#        -120.76, -120.88, -120.69, -120.93, -120.97, -120.87, -120.98,
#        -120.72, -120.77, -120.66, -120.62, -120.71, -121.83, -121.81,
#        -121.74, -121.68, -121.54, -121.51, -121.59, -121.58, -121.6 ,
# ...

# %%
#Visualizamos qué valores toma el campo latitude
df['latitude'].unique()
# Out:
# array([37.88, 37.86, 37.85, 37.84, 37.83, 37.82, 37.81, 37.8 , 37.79,
#        37.77, 37.78, 37.76, 37.75, 37.74, 37.73, 37.9 , 37.89, 37.87,
#        37.72, 37.71, 37.7 , 37.69, 37.68, 37.64, 37.63, 37.66, 37.65,
#        37.67, 37.61, 37.62, 37.6 , 37.59, 37.58, 37.57, 37.49, 37.52,
#        37.56, 37.55, 37.54, 37.53, 37.51, 37.48, 37.47, 37.5 , 38.69,
#        38.72, 38.52, 38.48, 38.45, 38.46, 38.43, 38.55, 38.54, 38.51,
#        38.5 , 38.47, 38.44, 38.42, 38.37, 38.34, 38.32, 38.26, 38.38,
#        38.4 , 38.39, 38.36, 38.31, 39.76, 39.78, 39.77, 39.74, 39.75,
#        39.73, 39.71, 39.72, 39.7 , 39.82, 39.79, 39.68, 39.64, 39.66,
#        39.59, 39.88, 40.06, 39.97, 39.86, 39.83, 39.8 , 39.69, 39.61,
#        39.65, 39.55, 39.52, 39.53, 39.6 , 39.54, 39.5 , 39.49, 39.51,
#        39.48, 39.47, 39.45, 39.44, 39.43, 39.4 , 39.39, 39.33, 39.37,
#        39.35, 39.34, 39.32, 39.36, 39.38, 39.42, 39.41, 38.15, 38.12,
# ...

# %%
#Visualizamos qué valores toma el campo housing_median_age
df['housing_median_age'].unique()
# Out:
# array([41., 21., 52., 42., 50., 40., 49., 48., 51., 43.,  2., 46., 26.,
#        20., 17., 36., 19., 23., 38., 35., 10., 16., 27., 39., 31., 29.,
#        22., 37., 28., 34., 32., 47., 44., 30., 18., 45., 33., 24., 15.,
#        14., 13., 25.,  5., 12.,  6.,  8.,  9.,  7.,  3.,  4., 11.,  1.])

# %%
#Visualizamos qué valores toma el campo total_rooms
df['total_rooms'].unique()
# Out:
# array([  880.,  7099.,  1467., ...,  4598.,   272., 10035.])

# %%
#Visualizamos qué valores toma el campo population
df['population'].unique()
# Out:
# array([ 322., 2401.,  496., ..., 3060., 2707., 6912.])

# %%
# PODRIAMOS HACERLO CON TODOS LOS CAMPOS PERO COMO SON MUCHOS DATOS DIFERENTES TAMPOCO SIRVE DE MUCHO

# %%
# Otra forma de ver cuantos elementos tienen NaN (o cualquier valor) en una columna
print('Numero de NaN en la columna:', df['median_income'].isna().sum())
# Out:
# Numero de NaN en la columna: 0

# %% [markdown]
# # Limpieza por cuartiles

# %%
# %matplotlib inline
df.boxplot('median_income')
# Out:
# <AxesSubplot:>

# %%
sP = df['median_income']
IQR = 1.5*(sP.quantile(.75)-sP.quantile(.25))
lim_sup = sP.quantile(.75)+IQR
lim_inf = sP.quantile(.25)-IQR
print('IQR: ', IQR, '\nQ75: ', sP.quantile(.75), '\nQ15: ', sP.quantile(.25), '\nlim_inf: ', lim_inf, '\nlim_sup: ', lim_sup)
# Out:
# IQR:  3.269775
# Q75:  4.74325
# Q15:  2.5633999999999997
# lim_inf:  -0.7063750000000004
# lim_sup:  8.013024999999999

# %%
import seaborn as sns
g = sns.histplot(data = df, x = 'median_house_value')
# Add labels
g.set_xlabel('median_house_value')
# Out:
# Text(0.5, 0, 'median_house_value')

# %%
df.boxplot('median_house_value')
# Out:
# <AxesSubplot:>

# %%
sP = df['median_house_value']
IQR = ((sP.quantile(0.75) - sP.quantile(0.25)))
lim_sup = sP.quantile(0.75) + 1.5 * IQR
lim_inf = sP.quantile(0.25) - 1.5 * IQR
print('IQR: ', IQR, '\nQ75: ', sP.quantile(0.75), '\nQ25: ', sP.quantile(0.25), '\nlim_inf: ', lim_inf, '\nlim_sup: ', lim_sup)
# Out:
# IQR:  145125.0
# Q75:  264725.0
# Q25:  119600.0
# lim_inf:  -98087.5
# lim_sup:  482412.5

# %%
# Create a box plot
g = sns.boxplot(data = df, x = 'median_house_value')

# Add a title and change xlabel
g.set_title('Box Plot of median_house_value')
g.set_xlabel('median_house_valuep')
# Out:
# Text(0.5, 0, 'median_house_valuep')

# %%
# Calculate the percentiles
Q75 = df['median_house_value'].quantile(0.75)
Q25 = df['median_house_value'].quantile(0.25)

# Obtain IQR
IQR = Q75 - Q25

# Upper and lower thresholds
lim_sup = Q75 + (1.5 * IQR)
lim_inf = Q25 - (1.5 * IQR)

print('IQR: ', IQR, '\nQ75: ', Q75, '\nQ25: ', Q25, '\nlim_inf: ', lim_inf, '\nlim_sup: ', lim_sup)

outliers = df[(df['median_house_value'] < lim_inf) | (df['median_house_value'] > lim_sup)]
print(f'Number of outliers: {len(outliers)}')
# Out:
# IQR:  145125.0
# Q75:  264725.0
# Q25:  119600.0
# lim_inf:  -98087.5
# lim_sup:  482412.5
# Number of outliers: 1071

# %%
sP_clean = sP[(sP >= lim_sup) | (sP <= lim_inf)]
sP_clean
# Out:
# 89       500001.0
# 140      483300.0
# 459      500001.0
# 489      489600.0
# 493      500001.0
#            ...
# 20422    500001.0
# 20426    500001.0
# 20427    500001.0
# 20436    500001.0
# 20443    500001.0
# Name: median_house_value, Length: 1071, dtype: float64

# %%
df.drop(sP_clean.index)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
med_inc = df['median_income']
for k in range (len(med_inc)):
    if (med_inc[k] < 0.):
        print(med_inc[k], '\n')

# %%
from plotnine import *
from plotnine import data
from pandas import DataFrame

p10 = ggplot(df) + geom_boxplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31680\867509437.py in <module>
# ----> 1 from plotnine import *
#       2 from plotnine import data
#       3 from pandas import DataFrame
#       4
#       5 p10 = ggplot(df) + geom_boxplot()
#
# ModuleNotFoundError: No module named 'plotnine'

# %% [markdown]
# # Limpieza por cuartiles

# %%
from scipy import stats
sP = df['median_income']
z = np.abs(stats.zscore(sP))
print(z, '\n')
sP_clean = sP[(z>3) | (z<-3)]
df.drop(sP_clean.index)

# %%
df.plot(x="median_income",y="median_house_value",kind="scatter")
